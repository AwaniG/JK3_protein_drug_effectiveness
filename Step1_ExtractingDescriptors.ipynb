# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
# read the csv
data = pd.read_csv("/content/drive/MyDrive/1:1_Awani_Gadre/Execution2/Dataset/Jake3.csv")
data.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0         NaN              NaN       129351                  []
# 1         NaN              NaN       506157                  []
# 2         NaN              NaN       512200                  []
# 3         NaN              NaN       592735                  []
# 4         NaN              NaN       596590                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL704118                       Inhibition of Janus kinase 3
# 1    CHEMBL872505                 Inhibition of protein kinase Jak 3
# 2    CHEMBL704115                          Inhibition of Jak3 kinase
# 3    CHEMBL704113  Inhibitory activity against Janus Kinase 3 pro...
# 4    CHEMBL704113  Inhibitory activity against Janus Kinase 3 pro...
#
#   assay_type  assay_variant_accession  assay_variant_mutation bao_endpoint  \
# 0          B                      NaN                     NaN  BAO_0000190
# 1          B                      NaN                     NaN  BAO_0000190
# 2          B                      NaN                     NaN  BAO_0000190
# 3          B                      NaN                     NaN  BAO_0000190
# 4          B                      NaN                     NaN  BAO_0000190
#
#    ... target_organism              target_pref_name target_tax_id text_value  \
# 0  ...    Homo sapiens  Tyrosine-protein kinase JAK3          9606        NaN
# 1  ...    Homo sapiens  Tyrosine-protein kinase JAK3          9606        NaN
# 2  ...    Homo sapiens  Tyrosine-protein kinase JAK3          9606        NaN
# 3  ...    Homo sapiens  Tyrosine-protein kinase JAK3          9606        NaN
# 4  ...    Homo sapiens  Tyrosine-protein kinase JAK3          9606        NaN
#
#   toid  type units    uo_units upper_value   value
# 0  NaN  IC50    uM  UO_0000065         NaN  10.000
# 1  NaN  IC50    uM  UO_0000065         NaN   0.005
# 2  NaN  IC50    uM  UO_0000065         NaN   0.044
# 3  NaN  IC50    uM  UO_0000065         NaN   0.870
# 4  NaN  IC50    uM  UO_0000065         NaN   0.213
#
# [5 rows x 46 columns]

# %%
# filter only the IC50 standard type
data_filter  = data[data["standard_type"] == "IC50"]
data_filter.reset_index(drop = True, inplace = True)
data_filter.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0         NaN              NaN       129351                  []
# 1         NaN              NaN       506157                  []
# 2         NaN              NaN       512200                  []
# 3         NaN              NaN       592735                  []
# 4         NaN              NaN       596590                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL704118                       Inhibition of Janus kinase 3
# 1    CHEMBL872505                 Inhibition of protein kinase Jak 3
# 2    CHEMBL704115                          Inhibition of Jak3 kinase
# 3    CHEMBL704113  Inhibitory activity against Janus Kinase 3 pro...
# 4    CHEMBL704113  Inhibitory activity against Janus Kinase 3 pro...
#
#   assay_type  assay_variant_accession  assay_variant_mutation bao_endpoint  \
# 0          B                      NaN                     NaN  BAO_0000190
# 1          B                      NaN                     NaN  BAO_0000190
# 2          B                      NaN                     NaN  BAO_0000190
# 3          B                      NaN                     NaN  BAO_0000190
# 4          B                      NaN                     NaN  BAO_0000190
#
#    ... target_organism              target_pref_name target_tax_id text_value  \
# 0  ...    Homo sapiens  Tyrosine-protein kinase JAK3          9606        NaN
# 1  ...    Homo sapiens  Tyrosine-protein kinase JAK3          9606        NaN
# 2  ...    Homo sapiens  Tyrosine-protein kinase JAK3          9606        NaN
# 3  ...    Homo sapiens  Tyrosine-protein kinase JAK3          9606        NaN
# 4  ...    Homo sapiens  Tyrosine-protein kinase JAK3          9606        NaN
#
#   toid  type units    uo_units upper_value   value
# 0  NaN  IC50    uM  UO_0000065         NaN  10.000
# 1  NaN  IC50    uM  UO_0000065         NaN   0.005
# 2  NaN  IC50    uM  UO_0000065         NaN   0.044
# 3  NaN  IC50    uM  UO_0000065         NaN   0.870
# 4  NaN  IC50    uM  UO_0000065         NaN   0.213
#
# [5 rows x 46 columns]

# %%
data_filter
# Out:
#                                             action_type activity_comment  \
# 0                                                   NaN              NaN
# 1                                                   NaN              NaN
# 2                                                   NaN              NaN
# 3                                                   NaN              NaN
# 4                                                   NaN              NaN
# ...                                                 ...              ...
# 4684  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 4685                                                NaN              NaN
# 4686  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 4687                                                NaN              NaN
# 4688                                                NaN              NaN
#
#       activity_id                                activity_properties  \
# 0          129351                                                 []
# 1          506157                                                 []
# 2          512200                                                 []
# 3          592735                                                 []
# 4          596590                                                 []
# ...           ...                                                ...
# 4684     24954033  [{'comments': None, 'relation': None, 'result_...
# 4685     24954034  [{'comments': None, 'relation': None, 'result_...
# 4686     24954333  [{'comments': None, 'relation': None, 'result_...
# 4687     24956651  [{'comments': None, 'relation': None, 'result_...
# 4688     24958601  [{'comments': None, 'relation': None, 'result_...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL704118                       Inhibition of Janus kinase 3
# 1       CHEMBL872505                 Inhibition of protein kinase Jak 3
# 2       CHEMBL704115                          Inhibition of Jak3 kinase
# 3       CHEMBL704113  Inhibitory activity against Janus Kinase 3 pro...
# 4       CHEMBL704113  Inhibitory activity against Janus Kinase 3 pro...
# ...              ...                                                ...
# 4684   CHEMBL5210194  Affinity On-target Cellular interaction (NanoB...
# 4685   CHEMBL5210195  Affinity On-target Cellular interaction (NanoB...
# 4686   CHEMBL5210451  Affinity Biochemical interaction (Radiometric ...
# 4687   CHEMBL5213043  Selectivity interaction (Z’-LYTE assay) EUB000...
# 4688   CHEMBL5213082  Selectivity interaction (33P-ATP and filter-bi...
#
#      assay_type  assay_variant_accession  assay_variant_mutation bao_endpoint  \
# 0             B                      NaN                     NaN  BAO_0000190
# 1             B                      NaN                     NaN  BAO_0000190
# 2             B                      NaN                     NaN  BAO_0000190
# 3             B                      NaN                     NaN  BAO_0000190
# 4             B                      NaN                     NaN  BAO_0000190
# ...         ...                      ...                     ...          ...
# 4684          B                      NaN                     NaN  BAO_0000190
# 4685          B                      NaN                     NaN  BAO_0000190
# 4686          B                      NaN                     NaN  BAO_0000190
# 4687          B                      NaN                     NaN  BAO_0000190
# 4688          B                      NaN                     NaN  BAO_0000190
#
#       ... target_organism              target_pref_name target_tax_id  \
# 0     ...    Homo sapiens  Tyrosine-protein kinase JAK3          9606
# 1     ...    Homo sapiens  Tyrosine-protein kinase JAK3          9606
# 2     ...    Homo sapiens  Tyrosine-protein kinase JAK3          9606
# 3     ...    Homo sapiens  Tyrosine-protein kinase JAK3          9606
# 4     ...    Homo sapiens  Tyrosine-protein kinase JAK3          9606
# ...   ...             ...                           ...           ...
# 4684  ...    Homo sapiens  Tyrosine-protein kinase JAK3          9606
# 4685  ...    Homo sapiens  Tyrosine-protein kinase JAK3          9606
# 4686  ...    Homo sapiens  Tyrosine-protein kinase JAK3          9606
# 4687  ...    Homo sapiens  Tyrosine-protein kinase JAK3          9606
# 4688  ...    Homo sapiens  Tyrosine-protein kinase JAK3          9606
#
#      text_value toid  type units    uo_units upper_value      value
# 0           NaN  NaN  IC50    uM  UO_0000065         NaN     10.000
# 1           NaN  NaN  IC50    uM  UO_0000065         NaN      0.005
# 2           NaN  NaN  IC50    uM  UO_0000065         NaN      0.044
# 3           NaN  NaN  IC50    uM  UO_0000065         NaN      0.870
# 4           NaN  NaN  IC50    uM  UO_0000065         NaN      0.213
# ...         ...  ...   ...   ...         ...         ...        ...
# 4684        NaN  NaN  IC50    nM  UO_0000065         NaN    100.000
# 4685        NaN  NaN  IC50    nM  UO_0000065         NaN  10000.000
# 4686        NaN  NaN  IC50    nM  UO_0000065         NaN      0.154
# 4687        NaN  NaN  IC50    µM         NaN         NaN     10.000
# 4688        NaN  NaN  IC50    nM  UO_0000065         NaN    580.000
#
# [4689 rows x 46 columns]

# %%
# check null values
null_values = data_filter["standard_value"].isnull().sum()
print("Nulls in standard value column: {}".format(null_values))
# if there are null values, drop them
if null_values > 0:
    print("Removing Nans in standard_value column")
    print("Shape before dropping the nulls: {}".format(data_filter.shape))
    data_filter_nans = data_filter[data_filter.standard_value.notna()]
    data_filter_nans.reset_index(drop = True, inplace = True)
    print("Shape after dropping the nulls: {}".format(data_filter_nans.shape))
else:
    print("No Nans in standard_value column")
    data_filter_nans = data_filter.copy()
# Out:
# Nulls in standard value column: 94
# Removing Nans in standard_value column
# Shape before dropping the nulls: (4689, 46)
# Shape after dropping the nulls: (4595, 46)

# %%
# check duplicates
duplicates = data_filter_nans["canonical_smiles"].duplicated().sum()
print("Number of duplicates in canonical_smiles cloumn: {}".format(duplicates))
if duplicates > 0:
    print("Removing Duplicates in canonical smiles column")
    print("Shape before dropping the duplicates: {}".format(data_filter_nans.shape))
    data_filter_dup = data_filter_nans.drop_duplicates(["canonical_smiles"])
    data_filter_dup.reset_index(drop = True, inplace = True)
    print("Shape after dropping the duplicates: {}".format(data_filter_dup.shape))
else:
    print("No duplicates in canonical smiles column")
    data_filter_dup = data_filter_nans.copy()
# Out:
# Number of duplicates in canonical_smiles cloumn: 441
# Removing Duplicates in canonical smiles column
# Shape before dropping the duplicates: (4595, 46)
# Shape after dropping the duplicates: (4154, 46)

# %%
# dropping Nans in canonical smiles column
null_smile = data_filter_dup["canonical_smiles"].isnull().sum()
print("Nulls in canonical smiles column: {}".format(null_smile))
if null_smile > 0:
    print("removing nulls in canonical smile column")
    print("Shape before dropping the nulls: {}".format(data_filter_dup.shape))
    data_filter_smile = data_filter_dup[data_filter_dup.canonical_smiles.notna()]
    data_filter_smile.reset_index(drop = True, inplace = True)
    print("Shape after dropping the nulls: {}".format(data_filter_smile.shape))
else:
    print("No nulls in canoical_smile column")
    data_filter_smile = data_filter_dup.copy()
# Out:
# Nulls in canonical smiles column: 0
# No nulls in canoical_smile column

# %%
# filter out the required columns
select_columns = ["canonical_smiles", "standard_value"]
df = data_filter_smile[select_columns]
df.head()
# Out:
#                                     canonical_smiles  standard_value
# 0  O=C1NCc2c(-c3ccc(F)cc3F)cc(C3CCNCC3)cc2N1c1c(C...         10000.0
# 1     CC(C)(C)c1nc2c3ccc(F)cc3c3c(=O)[nH]ccc3c2[nH]1             5.0
# 2            Cc1cccc(Cl)c1NC(=O)c1cnc(NC(=O)C2CC2)s1            44.0
# 3      O=C1Nc2ccc(NC(=O)c3ccccc3)cc2/C1=C/c1ccc[nH]1           870.0
# 4              O=C1Nc2ccc(C(=O)O)cc2/C1=C/c1ccc[nH]1           213.0

# %%
# convert IC50 to PIC50
import numpy as np
# Define the pIC50 calculation function
def pIC50(standard_value):
    molar = standard_value * (10**-9)  # Converts nM to M
    return -np.log10(molar)
df['pIC50']=df['standard_value'].apply(pIC50)
df.drop("standard_value", axis = 1, inplace = True)
df.head()
# Out:
# <ipython-input-13-f8db3b15632b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pIC50']=df['standard_value'].apply(pIC50)
# <ipython-input-13-f8db3b15632b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("standard_value", axis = 1, inplace = True)
#                                     canonical_smiles     pIC50
# 0  O=C1NCc2c(-c3ccc(F)cc3F)cc(C3CCNCC3)cc2N1c1c(C...  5.000000
# 1     CC(C)(C)c1nc2c3ccc(F)cc3c3c(=O)[nH]ccc3c2[nH]1  8.301030
# 2            Cc1cccc(Cl)c1NC(=O)c1cnc(NC(=O)C2CC2)s1  7.356547
# 3      O=C1Nc2ccc(NC(=O)c3ccccc3)cc2/C1=C/c1ccc[nH]1  6.060481
# 4              O=C1Nc2ccc(C(=O)O)cc2/C1=C/c1ccc[nH]1  6.671620

# %%
# sometime after converting to pIC50
# there can be null values
new_nulls = df["pIC50"].isnull().sum()
if new_nulls > 0:
    print("Removing nulls")
    print("Shape before removing nulls: {}".format(df.shape))
    df_no_null = df[df.pIC50.notna()]
    df_no_null.reset_index(drop = True, inplace = True)
    print("After removing nulls: {}".format(df_no_null.shape))
else:
    print("No Nulls")
    df_no_null = df.copy()
# Out:
# No Nulls

# %%
# save the dataframe
df_no_null.to_csv("/content/drive/MyDrive/1:1_Awani_Gadre/Execution2/Dataset/Jake3_processed.csv", index = False)
