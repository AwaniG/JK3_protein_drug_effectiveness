# %%
! pip install chembl_webresource_client
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client
# Target search for coronavirus
target = new_client.target
target_query = target.search('JAK3')
targets = pd.DataFrame.from_dict(target_query)
targets
selected_target = targets.target_chembl_id[0]
selected_target
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")
df = pd.DataFrame.from_dict(res)
df.head(3)
df.to_csv('JAK3_bioactivity_data_raw.csv', index=False)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 6.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jsonschema 4.19.0 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# referencing 0.30.2 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# ...

# %%
# Target search for JAK3
target = new_client.target
target_query = target.search('JAK3')
targets = pd.DataFrame.from_dict(target_query)
targets
# selected_target = targets.target_chembl_id[1]
# selected_target
# Out:
#                                     cross_references           organism  \
# 0  [{'xref_id': 'Q62137', 'xref_name': None, 'xre...       Mus musculus
# 1                                                 []  Rattus norvegicus
# 2  [{'xref_id': 'P52333', 'xref_name': None, 'xre...       Homo sapiens
# 3                                                 []       Mus musculus
# 4                                                 []       Homo sapiens
# 5                                                 []       Homo sapiens
# 6                                                 []       Homo sapiens
# 7                                                 []       Mus musculus
#
#                            pref_name  score  species_group_flag  \
# 0       Tyrosine-protein kinase JAK3   18.0               False
# 1       Tyrosine-protein kinase JAK3   18.0               False
# 2       Tyrosine-protein kinase JAK3   17.0               False
# ...

# %%
selected_target = targets.target_chembl_id[2]
selected_target
# Out:
# 'CHEMBL2148'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target)
df = pd.DataFrame.from_dict(res)
df.head(3)
df.to_csv('JAK3_bioactivity_data_raw.csv', index=False)

# %%
df.head(10)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       129351                  []
# 1        None             None       506157                  []
# 2        None             None       512200                  []
# 3        None             None       592735                  []
# 4        None             None       596590                  []
# 5        None             None       597821                  []
# 6        None             None       600307                  []
# 7        None             None       601569                  []
# 8        None             None       602753                  []
# 9        None             None       602754                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL704118                       Inhibition of Janus kinase 3
# 1    CHEMBL872505                 Inhibition of protein kinase Jak 3
# ...

# %%
df.describe()
# Out:
#         activity_id  document_year  potential_duplicate     record_id  \
# count  8.207000e+03    6555.000000          8207.000000  8.207000e+03
# mean   1.450769e+07    2015.108009             0.017912  2.372018e+06
# std    5.854474e+06       3.853424             0.132638  8.408266e+05
# min    1.293510e+05    2000.000000             0.000000  2.595400e+04
# 25%    9.624508e+06    2013.000000             0.000000  1.584704e+06
# 50%    1.631385e+07    2015.000000             0.000000  2.526219e+06
# 75%    1.821895e+07    2018.000000             0.000000  3.022968e+06
# max    2.495860e+07    2022.000000             1.000000  3.898534e+06
#
#             src_id  standard_flag
# count  8207.000000    8207.000000
# mean     13.309370       0.886560
# std      16.162197       0.317149
# min       1.000000       0.000000
# 25%       1.000000       1.000000
# 50%       1.000000       1.000000
# 75%      37.000000       1.000000
# max      65.000000       1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8207 entries, 0 to 8206
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   action_type                402 non-null    object
#  1   activity_comment           3295 non-null   object
#  2   activity_id                8207 non-null   int64
#  3   activity_properties        8207 non-null   object
#  4   assay_chembl_id            8207 non-null   object
#  5   assay_description          8207 non-null   object
#  6   assay_type                 8207 non-null   object
#  7   assay_variant_accession    0 non-null      object
#  8   assay_variant_mutation     0 non-null      object
#  9   bao_endpoint               8207 non-null   object
#  10  bao_format                 8207 non-null   object
#  11  bao_label                  8207 non-null   object
#  12  canonical_smiles           8207 non-null   object
# ...
