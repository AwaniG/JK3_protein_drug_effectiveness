# %%
# Import Libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# Load the Data Set
data = pd.read_csv('/content/gdrive/Shareddrives/1:1 Awani Gadre/Dataset/JAK3_descriptor_pIC50.csv')
data.head()
# Out:
#       pIC50  MaxAbsEStateIndex  MaxEStateIndex  MinAbsEStateIndex  \
# 0  5.000000          14.911933       14.911933           0.199792
# 1  8.301030          13.750318       13.750318           0.153872
# 2  7.356547          12.251818       12.251818           0.024763
# 3  6.060481          12.303131       12.303131           0.156356
# 4  6.671620          11.897902       11.897902           0.159848
#
#    MinEStateIndex       qed    MolWt  HeavyAtomMolWt  ExactMolWt  \
# 0       -0.653809  0.427700  488.365         467.197  487.102974
# 1       -0.367608  0.482368  309.344         293.216  309.127740
# 2       -0.291092  0.894383  335.816         321.704  335.049525
# 3       -0.187287  0.640131  329.359         314.239  329.116427
# 4       -1.012618  0.718379  254.245         244.165  254.069142
#
#    NumValenceElectrons  ...  fr_pyridine  fr_sulfide  fr_sulfonamd  \
# 0                  170  ...            0           0             0
# ...

# %%
# Split the data into train (80%) and test (20%)
X_train, X_test = train_test_split(data, test_size=0.2, random_state=42)

# Further split the train set into train (80%) and validation (20%)
X_train, X_val = train_test_split(X_train, test_size=0.2, random_state=42)

# Save the splits to separate CSV files
# X_train.to_csv('train.csv', index=False)
# X_val.to_csv('validation.csv', index=False)
# X_test.to_csv('test.csv', index=False)

# %%
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((2653, 196), (664, 196), (830, 196))

# %%
# Save the splits to separate CSV files
X_train.to_csv('/content/gdrive/Shareddrives/1:1 Awani Gadre/Dataset/train.csv', index=False)
X_val.to_csv('/content/gdrive/Shareddrives/1:1 Awani Gadre/Dataset/validation.csv', index=False)
X_test.to_csv('/content/gdrive/Shareddrives/1:1 Awani Gadre/Dataset/test.csv', index=False)
