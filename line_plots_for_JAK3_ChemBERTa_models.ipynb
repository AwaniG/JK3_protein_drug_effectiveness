# %% [markdown]
# ## Import modules

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Plot For MLP

# %%
X1 = [0.01,0.001,0.0001]
y1 = [1.08643, 1.29243, 1.24073]
# plotting the line 1 points
plt.plot(X1,y1, label = "hidden_layer_size = (50,50)")
X2 = [0.01,0.001,0.0001]
y2 = [0.96215, 1.08828, 1.43879]
plt.plot(X2, y2, label = "hidden_layer_size = (100,100)")
X3 = [0.01,0.001,0.0001]
y3 = [0.94824, 0.92746, 1.18074]
plt.plot(X3, y3, label = "hidden_layer_size = (200,100)")
X4 = [0.01,0.001,0.0001]
y4 = [0.93391, 0.92067, 1.13215]
plt.plot(X4, y4, label = "hidden_layer_size = (300,100)")
X5 = [0.01,0.001,0.0001]
y5 = [0.90924, 0.90566, 1.05386]
plt.plot(X5, y5, label = "hidden_layer_size = (400,100)")
X6 = [0.01,0.001,0.0001]
y6 = [0.96081, 0.87538, 0.97662]
plt.plot(X6, y6, label = "hidden_layer_size = (500,100)")

plt.legend(fontsize=8)

# Set plot labels
plt.xlabel('Learning Rate', fontsize=10)
plt.ylabel('Mean Squared Error (MSE)', fontsize=10)
# Remove the title
plt.title('')

# Remove the grid lines
plt.grid(False)

# Add a background grid for better readability
plt.grid(True, linestyle='--', alpha=0.6)

# Add a gray background for a cleaner appearance
#plt.gca().set_facecolor('lightgray')

# Adjust the y-axis range
plt.ylim(0.5, 1.5)

plt.show()
# Set a title of the current axes.
#plt.title('MLP_with_Molecular_desriptor ')

# %%
X1 = [0.01,0.001,0.0001]
y1 = [1.09675, 1.10908, 1.15194]
# plotting the line 1 points
plt.plot(X1,y1, label = "hidden_layer_size = (50,50)")
X2 = [0.01,0.001,0.0001]
y2 = [1.07815, 0.99725, 1.07514]
plt.plot(X2, y2, label = "hidden_layer_size = (100,100)")
X3 = [0.01,0.001,0.0001]
y3 = [1.1191, 1.0001, 1.05278]
plt.plot(X3, y3, label = "hidden_layer_size = (200,100)")
X4 = [0.01,0.001,0.0001]
y4 = [1.14622, 0.96343, 1.00566]
plt.plot(X4, y4, label = "hidden_layer_size = (300,100)")
X5 = [0.01,0.001,0.0001]
y5 = [1.10717, 0.97459, 0.99036]
plt.plot(X5, y5, label = "hidden_layer_size = (400,100)")
X6 = [0.01,0.001,0.0001]
y6 = [1.25633, 0.95875, 0.98844]
plt.plot(X6, y6, label = "hidden_layer_size = (500,100)")

plt.legend(fontsize=8)

# Set plot labels
plt.xlabel('Learning Rate', fontsize=10)
plt.ylabel('Mean Squared Error (MSE)', fontsize=10)
# Remove the title
plt.title('')

# Remove the grid lines
plt.grid(False)

# Add a background grid for better readability
plt.grid(True, linestyle='--', alpha=0.6)

# Add a gray background for a cleaner appearance
#plt.gca().set_facecolor('lightgray')

# Adjust the y-axis range
plt.ylim(0.5, 1.5)

plt.show()
# Set a title of the current axes.
#plt.title('MLP_with_ChemBERTa_Embeddings')

# %%
X1 = [0.01,0.001,0.0001]
y1 = [1.06807, 1.05664, 1.17222]
# plotting the line 1 points
plt.plot(X1,y1, label = "hidden_layer_size = (50,50)")
X2 = [0.01,0.001,0.0001]
y2 = [1.00173, 0.91771, 0.98241]
plt.plot(X2, y2, label = "hidden_layer_size = (100,100)")
X3 = [0.01,0.001,0.0001]
y3 = [1.21984, 0.91875, 0.92996]
plt.plot(X3, y3, label = "hidden_layer_size = (200,100)")
X4 = [0.01,0.001,0.0001]
y4 = [1.12522, 0.90662, 0.94625]
plt.plot(X4, y4, label = "hidden_layer_size = (300,100)")
X5 = [0.01,0.001,0.0001]
y5 = [1.33827, 0.87558, 0.906]
plt.plot(X5, y5, label = "hidden_layer_size = (400,100)")
X6 = [0.01,0.001,0.0001]
y6 = [1.1973, 0.9085, 0.90363]
plt.plot(X6, y6, label = "hidden_layer_size = (500,100)")

plt.legend(fontsize=8)

# Set plot labels
plt.xlabel('Learning Rate', fontsize=10)
plt.ylabel('Mean Squared Error (MSE)', fontsize=10)
# Remove the title
plt.title('')

# Remove the grid lines
plt.grid(False)

# Add a background grid for better readability
plt.grid(True, linestyle='--', alpha=0.6)

# Add a gray background for a cleaner appearance
#plt.gca().set_facecolor('lightgray')

# Adjust the y-axis range
plt.ylim(0.5, 1.5)

plt.show()

# Set a title of the current axes.
#plt.title('MLP_with_Molecular_descriptors_and_ChemBERTa_Embeddings')

# %% [markdown]
# ## Line Plot for XGBoost

# %%
X1 = [50,100,150,200,250]
y1 = [0.97272, 0.97093, 0.97024, 0.97029, 0.97038]
plt.plot(X1,y1, label = "ChemBERTa_Embeddings")
X2 = [50,100,150,200,250]
y2 = [0.83206, 0.8284, 0.8273, 0.82709, 0.82705]
plt.plot(X2,y2, label = "Molecular_Descriptors_and_ChemBERTa_Embeddings")
# X3 = [50,100,150,200,250]
# y3 = [0.81447, 0.81038, 0.80943, 0.80955, 0.80955]
# plt.plot(X3,y3, label = "Molecular_Descriptors_and_PubChem_Embeddings")

plt.legend(fontsize=8)

# Set plot labels
plt.xlabel('Number of Estimators', fontsize=10)
plt.ylabel('Mean Squared Error (MSE)', fontsize=10)
# Remove the title
plt.title('')

# Remove the grid lines
plt.grid(False)

# Add a background grid for better readability
plt.grid(True, linestyle='--', alpha=0.6)

# Add a gray background for a cleaner appearance
#plt.gca().set_facecolor('lightgray')

# Adjust the y-axis range
plt.ylim(0.5, 1.5)

plt.show()



#plt.title('Xgboost_all_3')

# %%
X1 = [50,100,150,200,250]
y1 = [0.97516, 0.97066, 0.96941, 0.96929, 0.96929]
# plotting MSE results
plt.plot(X1, y1)
plt.xlabel('num_estimators')
# Set the y axis label of the current axis.
plt.ylabel('MSE')
plt.title('Xgboost_with_PubChem_10M_Embeddings')

# %%
X1 = [50,100,150,200,250]
y1 = [0.81447, 0.81038, 0.80943, 0.80955, 0.80955]
# plotting MSE results
plt.plot(X1, y1)
plt.xlabel('num_estimators')
# Set the y axis label of the current axis.
plt.ylabel('MSE')
plt.title('Xgboost_with_Molecular_descriptors_and_PubChem_Embeddings')

# %% [markdown]
# ## Line plot for RF

# %%
# X1 = [100,150,200,250,300,350,500]
# y1 = [0.7353506193, 0.7340326483, 0.7320066445, 0.7294234869, 0.7299885454, 0.7293605866, 0.730977895]
# plt.plot(X1,y1, label = "Molecular_Descriptors")
X2 = [100,150,200,250,300,350,500]
y2 = [0.97784, 0.97648, 0.97044, 0.9676, 0.96654, 0.96683, 0.96259]
plt.plot(X2,y2, label = "ChemBERTa_Embeddings")
X3 = [100,150,200,250,300,350,500]
y3 = [0.86013, 0.86084, 0.85687, 0.85426, 0.85376, 0.85385, 0.85125]
plt.plot(X3,y3, label = "Molecular_Descriptors_and_ChemBERTa_Embeddings")
plt.legend(fontsize=8)

# Set plot labels
plt.xlabel('Number of Estimators', fontsize=10)
plt.ylabel('Mean Squared Error (MSE)', fontsize=10)
# Remove the title
plt.title('')

# Remove the grid lines
plt.grid(False)

# Add a background grid for better readability
plt.grid(True, linestyle='--', alpha=0.6)

# Add a gray background for a cleaner appearance
#plt.gca().set_facecolor('lightgray')

# Adjust the y-axis range
plt.ylim(0.5, 1.5)

plt.show()


#plt.title('Random_forest_all_3')

# %%
X1 = [100,150,200,250,300,350,500]
y1 = [0.97034, 0.96363, 0.96089, 0.96153, 0.95839, 0.9588, 0.9562]
# plotting MSE results
plt.plot(X1, y1)
plt.xlabel('num_estimators')
# Set the y axis label of the current axis.
plt.ylabel('MSE')
plt.title('Random_forest_PubChem_10M_Embeddings')

# %%
X1 = [100,150,200,250,300,350,500]
y1 = [0.85205, 0.84777, 0.84322, 0.84332, 0.84382, 0.84528, 0.84277]
# plotting MSE results
plt.plot(X1, y1)
plt.xlabel('num_estimators')
# Set the y axis label of the current axis.
plt.ylabel('MSE')
plt.title('Random_forest_with_Molecular_descriptors_and_PubChem_Embeddings')

# %% [markdown]
# ## Line plot for Chemberta

# %%
X1 = [10,50,100,200]
y1 = [2.3704681, 2.8499403, 2.889155, 2.879324]
# plotting the line 1 points
plt.plot(X1,y1, label = "learning_rate = 0.01")
X2 = [10,50,100,200]
y2 = [2.272075, 2.3788185, 2.5931516, 2.4130256]
plt.plot(X2, y2, label = "learning_rate = 0.005")
X3 = [10,50,100,200]
y3 = [2.2199414, 2.2149596, 2.237534, 2.2585707]
plt.plot(X3, y3, label = "learning_rate = 0.001")
X4 = [10,50,100,200]
y4 = [1.6645927, 1.9145314, 2.2036328, 2.2163777]
plt.plot(X4, y4, label = "learning_rate = 0.0005")
X5 = [10,50,100,200]
y5 = [0.96835405, 0.77440965, 0.7587668, 0.78773105]
plt.plot(X5, y5, label = "learning_rate = 0.0001")
plt.xlabel('hidden_layer_size')
# Set the y axis label of the current axis.
plt.ylabel('MSE')
plt.legend()
# Set a title of the current axes.
plt.title('ChemBerta')

# %%
X1 = [0.01,0.005, 0.001, 0.0005, 0.0001, 0.00001]
y1 = [2.364635, 2.270393, 2.2116733, 2.1996572, 0.8779439, 1.3030975]
# plotting the line 1 points
plt.plot(X1,y1, label = "Epochs = 10")
X2 = [0.01,0.005, 0.001, 0.0005, 0.0001, 0.00001]
y2 = [2.6383638, 2.6185849, 2.2066486, 2.2015982, 0.8369282, 1.097189]
plt.plot(X2, y2, label = "Epochs = 50")
X3 = [0.01,0.005, 0.001, 0.0005, 0.0001, 0.00001]
y3 = [2.6786666, 2.4004457, 2.248308, 2.2134967, 0.7871794, 0.9100089]
plt.plot(X3, y3, label = "Epochs = 100")
X4 = [0.01,0.005, 0.001, 0.0005, 0.0001, 0.00001]
y4 = [2.3135102, 2.2971213, 2.2147295, 2.1983242, 0.81076145, 0.87122697]
plt.plot(X4, y4, label = "Epochs = 200")

plt.legend(fontsize=8)

# Set plot labels
plt.xlabel('Learning Rate', fontsize=10)
plt.ylabel('Mean Squared Error (MSE)', fontsize=10)
# Remove the title
plt.title('')

# Remove the grid lines
plt.grid(False)

# Add a background grid for better readability
plt.grid(True, linestyle='--', alpha=0.6)

# Add a gray background for a cleaner appearance
#plt.gca().set_facecolor('lightgray')

# Adjust the y-axis range
plt.ylim(0.5, 3.0)

plt.show()

# Set a title of the current axes.
#plt.title('ChemBerta')
